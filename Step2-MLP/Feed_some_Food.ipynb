# %% [markdown]
# # Feed some Food
# Trying to feed some tasty text-tensors to our feedforward model

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# only for transforms
import torchvision
import torchvision.transforms as transforms

from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 0 Config and Parameters

# %%
# config
device = torch.device('cuda' if torch.cuda.is_available else 'cpu')

# hyperparameters
in_dim = 10001
hidden_dim = 100
out_dim = 4
epochs = 7 #90
batch = 500
lr = 0.01

# %% [markdown]
# ### 1 Dataloader

# %%
class MyDataset(Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform
        
    def __getitem__(self, index):
        x, y = self.subset[index]
        if self.transform:
            x = self.transform(x)
        return x, y
        
    def __len__(self):
        return len(self.subset)

# %%
data = pd.read_pickle('Data/big_chungus.pkl')
# dataset = dataset = MyDataset(data)

# drop id column
data = data.drop(['ID'], axis=1)
data.head()
# Out:
#                                               vector       stance
# 0  [[tensor(0., dtype=torch.float64), tensor(0., ...  [tensor(3)]
# 1  [[tensor(0., dtype=torch.float64), tensor(0., ...  [tensor(0)]
# 2  [[tensor(0., dtype=torch.float64), tensor(0., ...  [tensor(3)]
# 3  [[tensor(0., dtype=torch.float64), tensor(0., ...  [tensor(3)]
# 4  [[tensor(0., dtype=torch.float64), tensor(0., ...  [tensor(1)]

# %%
data['vector'][1]
# Out:
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)

# %%
train, test = train_test_split(data, test_size=0.2)
print(train.__len__())
# Out:
# 2691

# %%
train_loader = DataLoader(dataset=train, batch_size=10, shuffle=False, num_workers=1)
test_loader = DataLoader(dataset=test, batch_size=10, shuffle=False, num_workers=1)

# %% [markdown]
# ### 2 MLP Layers and Activation

# %%
# define neural net
class NN(nn.Module):
    def __init__(self, in_dim, hidden_dim, out_dim):
        super(NN, self).__init__()
        # define layers
        self.l1 = nn.Linear(in_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.l2 = nn.Linear(hidden_dim, out_dim)
    
    # applies layers with sample x
    def forward(self, x):
        out = self.l1(x)
        out = self.relu(out)
        out = self.l2(out)
        return out

model = NN(in_dim, hidden_dim, out_dim).to(device)

# %% [markdown]
# ### 3 Loss and Optimizer

# %%
criterion = nn.CrossEntropyLoss() # this also applies softmax for us
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ### 4 Training Loop and Batch Size

# %%
print(train.__len__())
# Out:
# 2691

# %%
train.reset_index()
for i in train.iterrows():
    print(i[1][0])
# Out:
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3162, 0.0000, 0.3162,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3780, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.4472, 0.0000, 0.4472,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3536, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.4082, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.4472, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3536, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3536, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.3333, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3780,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.4082, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.4082, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3015,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.2500, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3333, 0.0000, 0.3333,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.4082, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3536, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3333, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.5774, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.5774, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3015, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.3780, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.2582, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3162, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.4082, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.4472,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3015, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3780,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.2500, 0.2500, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0529, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3536, 0.3536, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3162, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3536, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3536,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3162, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.2582, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0317]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0512, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3780, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3536, 0.0000, 0.3536,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.4082, 0.0000, 0.4082,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3333, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.4472, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3780, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3333, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.4082,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3780, 0.0000, 0.3780,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3780, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.2887,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.3780, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3780, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.4472, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.4082, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3162, 0.0000, 0.3162,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.4082, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3015, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.3536, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3780,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3780,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3536, 0.3536, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3536, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.2774, 0.2774, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0415, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3333,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3780,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3333, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3333, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3333, 0.0000, 0.3333,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.5774, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3536, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3333,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3333, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.4082, 0.4082, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3333, 0.0000, 0.3333,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3536, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3162, 0.3162, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3780, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.2887, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3780, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.4472, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3015, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3162, 0.0000, 0.0000,  ..., 0.0000, 0.0290, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.2887, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3780,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3333, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3162, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0723, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.1204, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3162, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3536, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.5774, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.2887, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.3780, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3780, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3780, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3780, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3333, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.2887, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3333, 0.0000, 0.3333,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3162, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.4472,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3536, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.3780, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3780, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3162,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3780, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3333,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.4082,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3536, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3162, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3333, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3536, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3780, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0415, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.4082,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.3780, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0723, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0983, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3333,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.5774, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.5774, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3015, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3780, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.4472, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0950, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3015, 0.3015,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3333,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0848, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.4472, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3780,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3333,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3162, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.4082, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.4472, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3536, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.4082, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3536, 0.3536, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.3333, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.2887, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3536, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# ...
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3333, 0.3333, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.4082, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3780, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3015,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3536, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3015, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.3333, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.3162, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.4082, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3536, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3780, 0.0000, 0.3780,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3333, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3333,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.4082,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3015, 0.3015,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3536, 0.0000, 0.3536,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.4472, 0.0000, 0.4472,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3780,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3780,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3780,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3333, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3780, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3780,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3333, 0.0000, 0.3333,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3536, 0.3536, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3536,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0950, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3333, 0.0000, 0.3333,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3536,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.2887, 0.2887, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3536, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3015,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3333,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3536,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.2673, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.4082,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3536,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.4082, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3333, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3780,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.2236, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.4082, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.2887, 0.0000, 0.2887,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.3536, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.2236, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.4082,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0.3333, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3780, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.4082, 0.0000, 0.4082,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0425, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.3333,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.3780, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0317]],
#        dtype=torch.float64)
# tensor([[0.3536, 0.0000, 0.3536,  ..., 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]], dtype=torch.float64)

# %%
print(model(train['vector'][0].float()))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_124286/1463445874.py in <module>
# ----> 1 print(model(train['vector'][0].float()))
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %%
# one step for each batch
n_steps = train.__len__()
idx = 0
cuda0 = torch.device('cuda:0')
for epoch in range(epochs):
    # loop over & unpack batches
    for i in train.iterrows():
        vector = (i[1][0]).to(device) # data
        stance = (i[1][1]).to(device) # label
        
        # forward pass
        outputs = model(vector.float())
        loss = criterion(outputs, stance)
        
        # backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # print loss every 100th step\\\  (idx+1) % 100
        if (idx+1) % 1 == 0:
            print(f"epoch {epoch+1} / {epochs}, step {idx+1}/{n_steps}, loss = {loss.item():.4}")
            idx+=1

# %%
print(outputs)
# Out:
# tensor([[-14.9725, -23.9889, -18.6390,  18.3463]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)

# %% [markdown]
# ### 5 Evaluation

# %%
with torch.no_grad():
    n_correct = 0
    n_samples = 0
    for i in test.iterrows():
        
        vector = (i[1][0]).to(device) # data
        stance = (i[1][1]).to(device) # label
        
        # test the trained model
        outputs = model(vector.float())
        
        # value, index
        _, predictions = torch.max(outputs, 1)
        n_samples += stance.shape[0] # gives us n of samples of current batch
        n_correct += (predictions == stance).sum().item()
    
    # accuracy in percent
    acc = 100.0 * n_correct / n_samples
    if acc < 69.0:
        print(f'accuracy = {acc}')
    elif acc >= 69.0:
        print(f'accuracy = {acc}, 🎉🎉🎉')
# Out:
# accuracy = 76.96879643387815, 🎉🎉🎉

# %%
# save the model
torch.save(model.state_dict(), "./kowalsky.pth")

# %% [markdown]
# ### Visualisation

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

y_pred = []
y_true = []

# iterate over test data
for i in test.iterrows():
        inputs = (i[1][0]).to(device) # data
        labels = (i[1][1]).to(device) # label
        
        output = model(inputs.float()) # Feed Network

        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output) # Save Prediction
        
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) # Save Truth

agree = 0
disagree = 0
discuss = 0
unrelated = 0
for i in y_pred:
    if i == 0:
        agree +=1
    elif i == 1:
        disagree += 1
    elif i == 2:
        discuss += 1
    elif i == 3:
        unrelated += 1
    
print(f'PREDICT: agree [0]: {agree} \n disagree [1]: {disagree} \n discuss [2]: {discuss} \n unrelated [3]: {unrelated}')

agree = 0
disagree = 0
discuss = 0
unrelated = 0
for i in y_true:
    if i == 0:
        agree +=1
    elif i == 1:
        disagree += 1
    elif i == 2:
        discuss += 1
    elif i == 3:
        unrelated += 1

print(f'TRUE: agree [0]: {agree} \n disagree [1]: {disagree} \n discuss[2]: {discuss} \n unrelated[3]: {unrelated}')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_8723/579828818.py in <module>
#       7 # iterate over test data
#       8 for i in test.iterrows():
# ----> 9         inputs = (i[1][0]).to(device) # data
#      10         labels = (i[1][1]).to(device) # label
#      11
#
# RuntimeError: CUDA error: unspecified launch failure
# CUDA kernel errors might be asynchronously reported at some other API call,so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.

# %%
# constant for classes
classes = ('Agree', 'Disagree', 'Discuss', 'Unrelated')

# Build confusion matrix
cf_matrix = confusion_matrix(y_true, y_pred)
df_cm = pd.DataFrame(cf_matrix/np.sum(cf_matrix) *2.5, index = [i for i in classes],
                     columns = [i for i in classes])
plt.figure(figsize = (12,7))
sn.heatmap(df_cm, annot=True)

plt.savefig('output.png')
